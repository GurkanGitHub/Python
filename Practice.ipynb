# %%
import pandas as pd

# %%
df = pd.read_excel("C:/Users/Owner/Desktop/VWTouran.xlsx")

# %%
df.head()
# Out:
#                   Date                   Garage  Unnamed: 2  \
# 0  2022-07-01 00:00:00  SARL GARAGE LEBOULENGER    241976.0
# 1                  NaN                      NaN         NaN
# 2                  NaN                      NaN         NaN
# 3                  NaN                      NaN         NaN
# 4                  NaN                      NaN         NaN
#
#                               travail   Prix garantie  \
# 0                 Entretien vidange 2    NaN      NaN
# 1         Main d'oeuvre mecanique Tx1  35.25      NaN
# 2  huile titan GT1 PRO C3 5W30 AUL X4  50.00      NaN
# 3                      Filtre a huile  12.74      NaN
# 4             joint de vidange -unite   0.97      NaN
#
#                                         commentaires
# 0                                                NaN
# 1  vidange moteur, remplacer joint, controle etat...
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Garage', 'Unnamed: 2', 'travail', 'Prix', 'garantie',
#        'commentaires'],
#       dtype='object')

# %%
df.columns[2]
# Out:
# 'Unnamed: 2'

# %%
df.rename(columns = {"Unnamed: 2": "Kilometre"}, inplace=True) # raname is method. Method is associated with object/classes. Means it is implicitly used for an object for which it is called.
df.head()
# Out:
#                   Date                   Garage  Kilometre  \
# 0  2022-07-01 00:00:00  SARL GARAGE LEBOULENGER   241976.0
# 1                  NaN                      NaN        NaN
# 2                  NaN                      NaN        NaN
# 3                  NaN                      NaN        NaN
# 4                  NaN                      NaN        NaN
#
#                               travail   Prix garantie  \
# 0                 Entretien vidange 2    NaN      NaN
# 1         Main d'oeuvre mecanique Tx1  35.25      NaN
# 2  huile titan GT1 PRO C3 5W30 AUL X4  50.00      NaN
# 3                      Filtre a huile  12.74      NaN
# 4             joint de vidange -unite   0.97      NaN
#
#                                         commentaires
# 0                                                NaN
# 1  vidange moteur, remplacer joint, controle etat...
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df.dtypes
# Out:
# Date             object
# Garage           object
# Kilometre       float64
# travail          object
# Prix            float64
# garantie         object
# commentaires     object
# dtype: object

# %%
#df["Date"] = pd.to_datetime(df["Date"]) #ParserError: Unknown string format: 22 Fevrier 2021

# %%
df.Date.value_counts()
# Out:
# 2022-07-01 00:00:00    1
# 10 decembre 2020       1
# 22 julliet 2020        1
# 21 fevrier 2020        1
# 2022-06-24 00:00:00    1
# 03 julliet 2020        1
# 20 julliet 2020        1
# 06 fevrier 2020        1
# 13 novembre 2019       1
# 22 Fevrier 2021        1
# 13 fevrier 2020        1
# Name: Date, dtype: int64

# %%
df.Date.replace("20 julliet 2020", "20-07-2020", inplace=True)
df.Date.replace("13 fevrier 2020", "13-02-2020", inplace=True)
df.Date.replace("06 fevrier 2020", "06-02-2020", inplace=True)
df.Date.replace("13 novembre 2019", "13-11-2019", inplace=True)
df.Date.replace("10 decembre 2020", "10-12-2020", inplace=True)
df.Date.replace("22 Fevrier 2021", "22-02-2021", inplace=True)
df.Date.replace("2022-06-24 00:00:00", "24-06-2022", inplace=True)
df.Date.replace("03 julliet 2020", "03-07-2020", inplace=True)
df.Date.replace("2022-07-01 00:00:00", "01-07-2022", inplace=True)
df.Date.replace("21 fevrier 2020", "21-02-2020", inplace=True)
df.Date.replace("22 julliet 2020", "22-07-2020", inplace=True)

# %%
df.Date.value_counts()
# Out:
# 13-11-2019             1
# 20-07-2020             1
# 22-02-2021             1
# 2022-06-24 00:00:00    1
# 03-07-2020             1
# 06-02-2020             1
# 2022-07-01 00:00:00    1
# 10-12-2020             1
# 13-02-2020             1
# 21-02-2020             1
# 22-07-2020             1
# Name: Date, dtype: int64

# %%
#dict = {"2022-07-01 00:00:00": "2022-07-01", "2022-06-24 00:00:00": "2022-06-24",
                    #"22 Fevrier 2021":"2021-02-22" , "13 novembre 2019": "2019-11-13", 
                     #  "10 decembre 2020":"2020-12-10", "03 julliet 2020": "2020-07-03",
                      #"22 julliet 2020":"2020-07-22"  , 
                      #"21 fevrier 2020": "2020-02-21" , "20 julliet 2020":"2020-07-20",
                      #"06 fevrier 2020":"2020-02-06"  , "13 fevrier 2020": "2020-02-13"}
#df.Date = df.Date.map(dict)
#df.Date.value_counts()

# %%
df.dtypes
# Out:
# Date             object
# Garage           object
# Kilometre       float64
# travail          object
# Prix            float64
# garantie         object
# commentaires     object
# dtype: object

# %%
df["Date"] = pd.to_datetime(df.Date)

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Garage                  object
# Kilometre              float64
# travail                 object
# Prix                   float64
# garantie                object
# commentaires            object
# dtype: object

# %%
df.Date.value_counts()
# Out:
# 2020-07-20    1
# 2020-02-21    1
# 2021-02-22    1
# 2019-11-13    1
# 2020-10-12    1
# 2020-03-07    1
# 2022-07-01    1
# 2022-06-24    1
# 2020-02-13    1
# 2020-06-02    1
# 2020-07-22    1
# Name: Date, dtype: int64

# %%
df.head()
# Out:
#         Date                   Garage  Kilometre  \
# 0 2022-07-01  SARL GARAGE LEBOULENGER   241976.0
# 1        NaT                      NaN        NaN
# 2        NaT                      NaN        NaN
# 3        NaT                      NaN        NaN
# 4        NaT                      NaN        NaN
#
#                               travail   Prix garantie  \
# 0                 Entretien vidange 2    NaN      NaN
# 1         Main d'oeuvre mecanique Tx1  35.25      NaN
# 2  huile titan GT1 PRO C3 5W30 AUL X4  50.00      NaN
# 3                      Filtre a huile  12.74      NaN
# 4             joint de vidange -unite   0.97      NaN
#
#                                         commentaires
# 0                                                NaN
# 1  vidange moteur, remplacer joint, controle etat...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ### Use .str.startswith

# %%
df[df.travail.str.startswith("Entretien") == True]
#df.travail.startswith("Entretien") # AttributeError: 'Series' object has no attribute 'startswith'
# Out:
#         Date                   Garage  Kilometre              travail  Prix  \
# 0 2022-07-01  SARL GARAGE LEBOULENGER   241976.0  Entretien vidange 2   NaN
#
#   garantie commentaires
# 0      NaN          NaN

# %%
df.travail
# Out:
# 0                       Entretien vidange 2
# 1               Main d'oeuvre mecanique Tx1
# 2        huile titan GT1 PRO C3 5W30 AUL X4
# 3                            Filtre a huile
# 4                   joint de vidange -unite
#                       ...
# 64                                      NaN
# 65    VIDANGE BOITE DE VITESSE REMPLACEMENT
# 66                   main doeuvre 1,5 heure
# 67                      Filtre huile 282828
# 68                                 Huile BV
# Name: travail, Length: 69, dtype: object

# %%
df[df.travail.str.count("vidange") == 1.0]
# Out:
#         Date                   Garage  Kilometre                  travail  \
# 0 2022-07-01  SARL GARAGE LEBOULENGER   241976.0      Entretien vidange 2
# 4        NaT                      NaN        NaN  joint de vidange -unite
#
#    Prix garantie commentaires
# 0   NaN      NaN          NaN
# 4  0.97      NaN          NaN

# %%
df[df.travail.str.find("vidange") > 0]
# Out:
#         Date                   Garage  Kilometre                  travail  \
# 0 2022-07-01  SARL GARAGE LEBOULENGER   241976.0      Entretien vidange 2
# 4        NaT                      NaN        NaN  joint de vidange -unite
#
#    Prix garantie commentaires
# 0   NaN      NaN          NaN
# 4  0.97      NaN          NaN

# %%
df.Garage
# Out:
# 0     SARL GARAGE LEBOULENGER
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                ...
# 64                        NaN
# 65               GARAGE MALLE
# 66                        NaN
# 67                        NaN
# 68                        NaN
# Name: Garage, Length: 69, dtype: object

# %%
df[0:25]
# Out:
#          Date                   Garage  Kilometre  \
# 0  2022-07-01  SARL GARAGE LEBOULENGER   241976.0
# 1         NaT                      NaN        NaN
# 2         NaT                      NaN        NaN
# 3         NaT                      NaN        NaN
# 4         NaT                      NaN        NaN
# 5         NaT                      NaN        NaN
# 6         NaT                      NaN        NaN
# 7         NaT                      NaN        NaN
# 8         NaT                      NaN        NaN
# 9         NaT                      NaN        NaN
# 10        NaT                      NaN        NaN
# 11        NaT                      NaN        NaN
# 12        NaT                      NaN        NaN
# 13        NaT                      NaN        NaN
# 14        NaT                      NaN        NaN
# 15        NaT                      NaN        NaN
# 16        NaT                      NaN        NaN
# 17        NaT                      NaN        NaN
# ...

# %%
df.isnull().head()
# Out:
#     Date  Garage  Kilometre  travail   Prix  garantie  commentaires
# 0  False   False      False    False   True      True          True
# 1   True    True       True    False  False      True         False
# 2   True    True       True    False  False      True          True
# 3   True    True       True    False  False      True          True
# 4   True    True       True    False  False      True          True

# %%
df.shape
# Out:
# (69, 7)

# %%
df.dropna(axis = 0, how = "all", inplace = True)
df.shape
# Out:
# (56, 7)

# %%
df[0:18]
# Out:
#          Date                   Garage  Kilometre  \
# 0  2022-07-01  SARL GARAGE LEBOULENGER   241976.0
# 1         NaT                      NaN        NaN
# 2         NaT                      NaN        NaN
# 3         NaT                      NaN        NaN
# 4         NaT                      NaN        NaN
# 5         NaT                      NaN        NaN
# 6         NaT                      NaN        NaN
# 7         NaT                      NaN        NaN
# 8         NaT                      NaN        NaN
# 9         NaT                      NaN        NaN
# 10        NaT                      NaN        NaN
# 11        NaT                      NaN        NaN
# 12        NaT                      NaN        NaN
# 13        NaT                      NaN        NaN
# 14        NaT                      NaN        NaN
# 15        NaT                      NaN        NaN
# 16        NaT                      NaN        NaN
# 21 2022-06-24  SARL GARAGE LEBOULENGER   241976.0
#
# ...

# %%
df.Garage.value_counts()
# Out:
# SOS Courroie de distribution    4
# SARL GARAGE LEBOULENGER         2
# SARL Garage Basnier             1
# GARAGE MALLE                    1
# SARL LEBRETHON                  1
# SE Garage de l'ouest            1
# l'auto E.LECLERC, Ifs auto      1
# Name: Garage, dtype: int64

# %%
df["Garage"] = df.Garage.replace("SARL GARAGE LEBOULENGER", "SARL Garage Leboulanger")

# %%
df.Garage.value_counts()
# Out:
# SOS Courroie de distribution    4
# SARL Garage Leboulanger         2
# SARL Garage Basnier             1
# GARAGE MALLE                    1
# SARL LEBRETHON                  1
# SE Garage de l'ouest            1
# l'auto E.LECLERC, Ifs auto      1
# Name: Garage, dtype: int64

# %%
df.head()
# Out:
#   Date                   Garage  Kilometre  \
# 0  NaT  SARL Garage Leboulanger   241976.0
# 1  NaT                      NaN        NaN
# 2  NaT                      NaN        NaN
# 3  NaT                      NaN        NaN
# 4  NaT                      NaN        NaN
#
#                               travail   Prix garantie  \
# 0                 Entretien vidange 2    NaN      NaN
# 1         Main d'oeuvre mecanique Tx1  35.25      NaN
# 2  huile titan GT1 PRO C3 5W30 AUL X4  50.00      NaN
# 3                      Filtre a huile  12.74      NaN
# 4             joint de vidange -unite   0.97      NaN
#
#                                         commentaires
# 0                                                NaN
# 1  vidange moteur, remplacer joint, controle etat...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.Date.value_counts()
# Out:
# 2020-07-03    1
# 2020-07-20    1
# 2020-12-10    1
# 2020-02-21    1
# 2021-02-22    1
# 2019-11-13    1
# 2020-02-13    1
# 2020-02-06    1
# 2020-07-22    1
# Name: Date, dtype: int64

# %%
df[df.Date == "2020-07-22"]
# Out:
#          Date                Garage  Kilometre        travail  Prix garantie  \
# 35 2020-07-22  SE Garage de l'ouest   220678.0  reparateur TG   NaN      NaN
#
#    commentaires
# 35          NaN
