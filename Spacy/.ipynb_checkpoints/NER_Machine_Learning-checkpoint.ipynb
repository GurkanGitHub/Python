# %%
import spacy

# %%
test = """Mr. Dursley was the director of a firm called Grunnings, which made drills.
He was a big, beefy man with hardly any neck, although he did have a very large mustache. 
Mrs. Dursley was thin and blonde and had nearly twice the usual amount of neck, which came 
in very useful as she spent so much of her time craning over garden fences, spying on the neighbors. 
The Dursleys had a small son called Dudley and in their opinion there was no finer boy anywhere."""

# %%
nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp(test)

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Dursley PERSON
# Grunnings ORG
# Dursley PERSON
# Dursleys ORG
# Dudley PERSON

# %%
# spaCy has been trained on multiple corpus-750Million words, it generate vocab, understand them numerically, then put words into vectors. 
# further trained model to recognize entities. It recog Mr.Dursley as person even though it never see before. It understand from context. 
#Model does calculated guess: When you change it to Vernon Dursley, it gives ORG. 
#ML NER is much more effective

# %%
import json

# %%
from spacy.lang.en import English

# %%
from spacy.pipeline import EntityRuler

# %%
def load_data(file):
    with open(file, "r", encoding="utf-8") as f:
        data=json.load(f)
    return(data)

# %%
def generate_better_characters(file):
    data = load_data(file)
    new_characters = []
    print(len(data))
    for item in data:
        new_characters.append(item)
    for item in data:
        item = item.replace("The", "").replace("the", "").replace("And", "").replace("and", "")
        names = item.split(" ")
        for name in names:
            name= name.strip()
            new_characters.append(name)
        if "(" in item:
            names=item.split("(")
            for name in names:
                name= name.replace(")", "").strip()
                new_characters.append(name)
        if "," in item:
            names=item.split(",")
            for name in names:
                name= name.replace("and", "").strip()
                if " " in name:
                    new_names = name.split()
                    for x in new_names:
                        x = x.strip()
                        new_characters.append(x)
                new_characters.append(name)
    print(len(new_characters))
    final_characters= []
    titles = ["Dr.", "Professor", "Mr.", "Mrs.", "Ms.", "Miss", "Aunt", "Uncle", "Mr. and Ms."] 
    
    for character in new_characters:
        if "" != character:
            final_characters.append(character)
            for title in titles:
                titled_char= f"{title}{character}"
                final_characters.append(titled_char)
    
    print(len(final_characters))    
    final_characters= list(set(final_characters))# deletes duplicates    
    print(len(final_characters))
    return(final_characters)

# %% [markdown]
# **Training entity ruler**

# %%
def create_training_data(file,type):
    data = generate_better_characters(file)
    patterns = []
    for item in data:
        pattern = {
            "label": type,
            "pattern":item
        }
        patterns.append(pattern)
    return(patterns)
#patterns = create_training_data("C:/Users/Owner/ner_youtube/data/hp_characters.json", "PERSON")
#print(patterns)
# Out:
# 207
# 622
# 6160
# 5120
# [{'label': 'PERSON', 'pattern': 'UncleAlice Longbottom'}, {'label': 'PERSON', 'pattern': 'MissLovegood'}, {'label': 'PERSON', 'pattern': 'Mrs.Salazar'}, {'label': 'PERSON', 'pattern': 'Rubeus Hagrid'}, {'label': 'PERSON', 'pattern': 'MissAmos'}, {'label': 'PERSON', 'pattern': 'ProfessorDumbledore'}, {'label': 'PERSON', 'pattern': 'AuntDavies'}, {'label': 'PERSON', 'pattern': 'ProfessorRufus'}, {'label': 'PERSON', 'pattern': 'Dr.The Grey Lady'}, {'label': 'PERSON', 'pattern': 'MissRita Skeeter'}, {'label': 'PERSON', 'pattern': 'Nearly Headless Nick'}, {'label': 'PERSON', 'pattern': 'Ms.Sturgis Podmore'}, {'label': 'PERSON', 'pattern': 'Mrs.Albus Dumbledore'}, {'label': 'PERSON', 'pattern': 'Mr.Shunpike'}, {'label': 'PERSON', 'pattern': 'AuntBogrod'}, {'label': 'PERSON', 'pattern': 'Dr.Nigellus'}, {'label': 'PERSON', 'pattern': 'Dr.Cedric'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Rabastan'}, {'label': 'PERSON', 'pattern': 'Crouch'}, {'label': 'PERSON', 'pattern': 'Mrs.Moaning Myrtle'}, {'label': 'PERSON', 'pattern': 'AuntMundungus Fletcher'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Sprout'}, {'label': 'PERSON', 'pattern': 'UncleKingsley Shacklebolt'}, {'label': 'PERSON', 'pattern': 'UncleScabior'}, {'label': 'PERSON', 'pattern': 'Mrs.Hooch'}, {'label': 'PERSON', 'pattern': 'Mrs.Rodolphus Lestrange'}, {'label': 'PERSON', 'pattern': 'AuntRola'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Lily Potter'}, {'label': 'PERSON', 'pattern': 'Olympe Maxime'}, {'label': 'PERSON', 'pattern': 'UncleGraham Montague'}, {'label': 'PERSON', 'pattern': 'Kingsley'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Vane'}, {'label': 'PERSON', 'pattern': 'ProfessorSturgis'}, {'label': 'PERSON', 'pattern': 'Ms.Pettigrew'}, {'label': 'PERSON', 'pattern': 'Mr.Corban Yaxley'}, {'label': 'PERSON', 'pattern': 'MissCharlie Weasley'}, {'label': 'PERSON', 'pattern': 'Mrs.Olympe Maxime'}, {'label': 'PERSON', 'pattern': 'Morfin'}, {'label': 'PERSON', 'pattern': 'Mr.Severus Snape'}, {'label': 'PERSON', 'pattern': 'Ms.Amos Diggory'}, {'label': 'PERSON', 'pattern': 'Mrs.Petunia Dursley'}, {'label': 'PERSON', 'pattern': 'Mr.Alastor (Mad-Eye) Moody'}, {'label': 'PERSON', 'pattern': 'MissStan Shunpike'}, {'label': 'PERSON', 'pattern': 'AuntKreacher'}, {'label': 'PERSON', 'pattern': 'AuntFlorean'}, {'label': 'PERSON', 'pattern': 'Mr.Peter Pettigrew'}, {'label': 'PERSON', 'pattern': 'AuntRose'}, {'label': 'PERSON', 'pattern': 'ProfessorYaxley'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Amelia Bones'}, {'label': 'PERSON', 'pattern': 'Dr.Percy Weasley'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Elphias Doge'}, {'label': 'PERSON', 'pattern': 'AuntRon'}, {'label': 'PERSON', 'pattern': 'Dr.Corner'}, {'label': 'PERSON', 'pattern': 'ProfessorRita'}, {'label': 'PERSON', 'pattern': 'UncleGarrick'}, {'label': 'PERSON', 'pattern': 'Dr.John Dawlish'}, {'label': 'PERSON', 'pattern': 'Ms.Salazar'}, {'label': 'PERSON', 'pattern': 'Ms.Arthur'}, {'label': 'PERSON', 'pattern': 'Mr.Thorfinn'}, {'label': 'PERSON', 'pattern': 'Mr.Blaise Zabini'}, {'label': 'PERSON', 'pattern': 'Mr.Bryce'}, {'label': 'PERSON', 'pattern': 'AuntNeville'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Mrs. Cole'}, {'label': 'PERSON', 'pattern': 'UncleGriselda'}, {'label': 'PERSON', 'pattern': 'Mrs.Stan Shunpike'}, {'label': 'PERSON', 'pattern': 'AuntCadmus,'}, {'label': 'PERSON', 'pattern': 'Elphias'}, {'label': 'PERSON', 'pattern': 'Gellert'}, {'label': 'PERSON', 'pattern': 'AuntMacmillan'}, {'label': 'PERSON', 'pattern': 'ProfessorOlympe'}, {'label': 'PERSON', 'pattern': 'MissVance'}, {'label': 'PERSON', 'pattern': 'ProfessorMarietta Edgecombe'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Fawkes'}, {'label': 'PERSON', 'pattern': 'Ms.Horace Slughorn'}, {'label': 'PERSON', 'pattern': 'Ms.Sinistra'}, {'label': 'PERSON', 'pattern': 'AuntIrma'}, {'label': 'PERSON', 'pattern': 'UncleTed'}, {'label': 'PERSON', 'pattern': 'UnclePoppy'}, {'label': 'PERSON', 'pattern': 'Mr. and Ms.Ron'}, {'label': 'PERSON', 'pattern ...

# %% [markdown]
# **Detecting entities in Harry Potter with NLP Model**

# %%
def generate_rules(patterns):
    nlp = English()
    ruler= EntityRuler(nlp)
    ruler.add_patterns(patterns)
    nlp.add_pipe(ruler)
    nlp.to_disk("hp_ner")

# %%
# !python -m spacy download hp_ner
# Out:
# [x] No compatible package found for 'hp_ner' (spaCy v3.6.0)

# %%
nlp = spacy.load("C:/Users/Owner/hp_ner/hp_ner")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 nlp = spacy.load("C:/Users/Owner/hp_ner/hp_ner")
#
# File ~\anaconda3\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~\anaconda3\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'C:/Users/Owner/hp_ner/hp_ner'. It doesn't seem to be a Python package or a valid path to a data directory.
