# %% [markdown]
# # The Correlates of War Project

# %% [markdown]
# COW War Data, 1816 - 2007 (v4.0)

# %% [markdown]
# Sarkees, Meredith Reid and Frank Wayman (2010). Resort to War: 1816 - 2007. Washington DC: CQ Press.

# %% [markdown]
# https://correlatesofwar.org/data-sets/COW-war

# %%
import pandas as pd

# %%
import zipfile

# %%
pwd
# Out:
# 'D:\\github\\Python'

# %%
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## Inter-state wars

# %%
inters = pd.read_csv("D:/PhD/Dataset/The_CoW_Project/COW_War_Data_1816-2007_(v4.0)/Inter-StateWarData_v4.0.csv", encoding = "latin-1")
# inters = pd.read_csv("https://correlatesofwar.org/data-sets/COW-war/inter-state-war-data/at_download/file", encoding = "latin-1")

# %%
inters.head()
# Out:
#    WarNum              WarName  WarType  ccode       StateName  Side  \
# 0       1   Franco-Spanish War        1    230           Spain     2
# 1       1   Franco-Spanish War        1    220          France     1
# 2       4  First Russo-Turkish        1    640  Ottoman Empire     2
# 3       4  First Russo-Turkish        1    365          Russia     1
# 4       7     Mexican-American        1     70          Mexico     2
#
#    StartMonth1  StartDay1  StartYear1  EndMonth1  ...  EndMonth2  EndDay2  \
# 0            4          7        1823         11  ...         -8       -8
# 1            4          7        1823         11  ...         -8       -8
# 2            4         26        1828          9  ...         -8       -8
# 3            4         26        1828          9  ...         -8       -8
# 4            4         25        1846          9  ...         -8       -8
#
#    EndYear2  TransFrom  WhereFought  Initiator  Outcome  TransTo BatDeath  \
# ...

# %%
inters.WarName.nunique()
# Out:
# 95

# %%
print("Minimum start year in interstate war list is: {}".format(inters.StartYear1.min()))
print("Maximum start year in interstate war list is: {}".format(inters.StartYear1.max()))
# Out:
# Minimum start year in interstate war list is: 1823
# Maximum start year in interstate war list is: 2003

# %%
# pip install pyreadstat
# import pyreadstat
# dtafile = 'MIDA 5.0.dta'
# MIDAdata = pyreadstat.read_dta(dtafile)

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WarNum       337 non-null    int64
#  1   WarName      337 non-null    object
#  2   WarType      337 non-null    int64
#  3   ccode        337 non-null    int64
#  4   StateName    337 non-null    object
#  5   Side         337 non-null    int64
#  6   StartMonth1  337 non-null    int64
#  7   StartDay1    337 non-null    int64
#  8   StartYear1   337 non-null    int64
#  9   EndMonth1    337 non-null    int64
#  10  EndDay1      337 non-null    int64
#  11  EndYear1     337 non-null    int64
#  12  StartMonth2  337 non-null    int64
#  13  StartDay2    337 non-null    int64
#  14  StartYear2   337 non-null    int64
#  15  EndMonth2    337 non-null    int64
#  16  EndDay2      337 non-null    int64
#  17  EndYear2     337 non-null    int64
#  18  TransFrom    337 non-null    object
# ...

# %%
ins.loc[1,:]
# Out:
# WarNum                          1
# WarName        Franco-Spanish War
# WarType                         1
# ccode                         220
# StateName                  France
# Side                            1
# StartMonth1                     4
# StartDay1                       7
# StartYear1                   1823
# EndMonth1                      11
# EndDay1                        13
# EndYear1                     1823
# StartMonth2                    -8
# StartDay2                      -8
# StartYear2                     -8
# EndMonth2                      -8
# EndDay2                        -8
# EndYear2                       -8
# TransFrom                     503
# WhereFought                     2
# Initiator                       1
# Outcome                         1
# TransTo                        -8
# BatDeath                      400
# Version                         4
# Name: 1, dtype: object

# %%
ins[ins.BatDeath > 1000].WarName.nunique()
# Out:
# 79

# %% [markdown]
# ## Extra-state wars

# %%
extras = pd.read_csv("D:/PhD/Dataset/The_CoW_Project/COW_War_Data_1816-2007_(v4.0)/Extra-StateWarData_v4.0.csv", encoding = "latin-1")

# %%
extras.head()
# Out:
#    WarNum                        WarName  WarType  ccode1           SideA  \
# 0     300  Allied Bombardment of Algiers        3     210     Netherlands
# 1     300  Allied Bombardment of Algiers        3     200  United Kingdom
# 2     301                Ottoman-Wahhabi        3     640  Ottoman Empire
# 3     302            Liberation of Chile        2     230           Spain
# 4     303       First Bolivar Expedition        2     230           Spain
#
#    ccode2                       SideB  StartMonth1  StartDay1  StartYear1  \
# 0      -8                          -8            8         26        1816
# 1      -8                     Algeria            8         26        1816
# 2      -8              Saudi Wahhabis            9         -9        1816
# 3      -8  San Martin revolutionaries            1          9        1817
# 4      -8                 New Granada            4         11        1817
#
#    ...  EndYear2  Initiator  Interven  TransFrom  Outcome  TransTo  \
# ...

# %%
extras.WarName.nunique()
# Out:
# 162

# %%
print("Minimum start year in extrastate war list is: {}".format(extras.StartYear1.min()))
print("Maximum start year in extrastate war list is: {}".format(extras.StartYear1.max()))
# Out:
# Minimum start year in extrastate war list is: 1816
# Maximum start year in extrastate war list is: 2004

# %% [markdown]
# ## Non-state wars

# %%
nons = pd.read_csv("D:/PhD/Dataset/The_CoW_Project/COW_War_Data_1816-2007_(v4.0)/Non-StateWarData_v4.0.csv", encoding = "latin-1")

# %%
nons.head()
# Out:
#    WarNum                  WarName  WarType  WhereFought  \
# 0    1500   First Maori Tribal War        8            9
# 1    1501     Shaka Zulu-Bantu War        8            4
# 2    1502          Burma-Assam War        8            7
# 3    1503         Buenos Aires War        8            1
# 4    1505  Second Maori Tribal War        8            9
#
#                      SideA1 SideA2      SideB1       SideB2  \
# 0  Te Rauparaha's Ngati Toa     -8    Taranaki    Ngai Tahu
# 1                Shaka Zulu     -8       Bantu           -8
# 2                     Burma     -8       Assam           -8
# 3              Buenos Aires     -8   Provinces           -8
# 4    Hongi Hika's Nga Phuhi     -8  Ngati Paoa   Ngati Maru
#
#                  SideB3      SideB4  ... EndMonth  EndDay  Initiator  \
# 0               Waikato   Ngati Ira  ...       -9      -9          A
# 1                    -8          -8  ...        9      24          A
# ...

# %%
nons.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'WhereFought', 'SideA1', 'SideA2',
#        'SideB1', 'SideB2', 'SideB3', 'SideB4', 'SideB5', 'StartYear',
#        'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Initiator',
#        'TransFrom', 'TransTo', 'Outcome', 'SideADeaths', 'SideBDeaths',
#        'TotalCombatDeaths', 'Version'],
#       dtype='object')

# %%
nons.WarName.nunique()
# Out:
# 62

# %%
print("Minimum start year in nonstate war list is: {}".format(nons.StartYear.min()))
print("Maximum start year in nonstate war list is: {}".format(nons.StartYear.max()))
# Out:
# Minimum start year in nonstate war list is: 1818
# Maximum start year in nonstate war list is: 1999

# %% [markdown]
# ## Intra-state wars

# %%
intras = pd.read_csv("D:/PhD/Dataset/The_CoW_Project/COW_War_Data_1816-2007_(v4.0)/Intra-StateWarData_v4.1.csv", encoding = "latin-1")

# %%
intras.head()
# Out:
#    WarNum             WarName  WarType  CcodeA         SideA  CcodeB  \
# 0     500      First Caucasus        5   365.0        Russia    -8.0
# 1     501      Sidon-Damascus        6    -8.0         Sidon    -8.0
# 2     502  First Two Sicilies        4   300.0       Austria    -8.0
# 3     502  First Two Sicilies        4   329.0  Two Sicilies    -8.0
# 4     503   Spanish Royalists        4   230.0         Spain    -8.0
#
#                               SideB  Intnl  StartMonth1  StartDay1  ...  \
# 0  Georgians, Dhagestania, Chechens      0            6         10  ...
# 1                 Damascus & Aleppo      0            6         -9  ...
# 2                                -8      1            3         -9  ...
# 3                          Liberals      1            7          2  ...
# 4                         Royalists      0           12          1  ...
#
#    EndDay2  EndYear2  TransFrom  WhereFought  Initiator  Outcome  TransTo  \
# ...

# %%
intras.WarName.nunique()
# Out:
# 332

# %%
print("Minimum start year in intra state war list is: {}".format(intras.StartYear1.min()))
print("Maximum start year in intra state war list is: {}".format(intras.StartYear1.max()))
# Out:
# Minimum start year in intra state war list is: 1818
# Maximum start year in intra state war list is: 2007

# %% [markdown]
# # National Material Capabilities (v5.0)

# %% [raw]
# Singer, J. David, Stuart Bremer, and John Stuckey. (1972). "Capability Distribution, Uncertainty, and Major Power War, 1820-1965." in Bruce Russett (ed) Peace, War, and Numbers, Beverly Hills: Sage, 19-48.

# %% [raw]
# https://correlatesofwar.org/data-sets/national-material-capabilities?searchterm=capability

# %%
import pandas as pd
import zipfile

# %% [raw]
# r = requests.get("https://correlatesofwar.org/data-sets/national-material-capabilities/nmc_documentation-6-0.zip/@@download/file/NMC_Documentation%206.0.zip")

# %% [raw]
# with open("data.zip", "wb") as f:
#     f.write(r.content)

# %% [raw]
# with zipfile.ZipFile("data.zip", "r") as nmc:
#     print(nmc.namelist())

# %% [raw]
# with zipfile.ZipFile("data.zip", "r") as nmc:
#     print(nmc.extractall())

# %% [raw]
# with zipfile.ZipFile("NMC-60-abridged.zip", "r") as nmc:
#     print(nmc.namelist())

# %% [raw]
# with zipfile.ZipFile("NMC-60-abridged.zip", "r") as nmc:
#     nmc.extractall("nmc")

# %%
nmc= pd.read_csv("D:/PhD/Dataset/CoW/nmc/NMC-60-abridged.csv")
nmc.head()
# Out:
#   stateabb  ccode  year  milex  milper  irst  pec    tpop   upop      cinc  \
# 0      USA      2  1816   3823      17    80  254  8659.0  101.0  0.039697
# 1      USA      2  1817   2466      15    80  277  8899.0  106.0  0.035817
# 2      USA      2  1818   1910      14    90  302  9139.0  112.0  0.036127
# 3      USA      2  1819   2301      13    90  293  9379.0  118.0  0.037133
# 4      USA      2  1820   1556      15   110  303  9618.0  124.0  0.037087
#
#    version
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021

# %%
nmc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15951 entries, 0 to 15950
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   stateabb  15951 non-null  object
#  1   ccode     15951 non-null  int64
#  2   year      15951 non-null  int64
#  3   milex     15951 non-null  int64
#  4   milper    15951 non-null  int64
#  5   irst      15951 non-null  int64
#  6   pec       15951 non-null  int64
#  7   tpop      15951 non-null  float64
#  8   upop      15951 non-null  float64
#  9   cinc      15951 non-null  float64
#  10  version   15951 non-null  int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 1.3+ MB

# %%
nmc.describe()
# Out:
#               ccode          year         milex        milper           irst  \
# count  15951.000000  15951.000000  1.595100e+04  15951.000000   15951.000000
# mean     399.135101   1953.706037  2.846920e+06    155.828914    3466.608363
# std      251.993959     52.956548  2.249296e+07    507.084316   22085.073238
# min        2.000000   1816.000000 -9.000000e+00     -9.000000      -9.000000
# 25%      200.000000   1922.000000  9.600000e+02      5.000000       0.000000
# 50%      365.000000   1971.000000  3.000000e+04     24.000000       0.000000
# 75%      616.000000   1996.000000  3.980000e+05    107.000000     460.000000
# max      990.000000   2016.000000  6.936000e+08  12500.000000  822698.000000
#
#                 pec          tpop           upop          cinc  version
# count  1.595100e+04  1.595100e+04   15951.000000  1.595100e+04  15951.0
# mean   5.248428e+04  2.710300e+04    5339.769647  1.290866e-02   2021.0
# ...

# %%
nmc.iloc[1:4,:]
# Out:
#   stateabb  ccode  year  milex  milper  irst  pec    tpop   upop      cinc  \
# 1      USA      2  1817   2466      15    80  277  8899.0  106.0  0.035817
# 2      USA      2  1818   1910      14    90  302  9139.0  112.0  0.036127
# 3      USA      2  1819   2301      13    90  293  9379.0  118.0  0.037133
#
#    version
# 1     2021
# 2     2021
# 3     2021

# %%
nmc.stateabb.nunique()
# Out:
# 217

# %%
# nmc.pivot_table("milex", index = "stateabb", columns="year")

# %%
nmc[nmc.stateabb == "USA"].plot("year", "milex", kind="line", figsize=(9,6))

# %%
nmc[nmc.stateabb == "TUR"].plot("year", "milex", kind="line", figsize=(12,6))

# %%
nmc.groupby("stateabb")["milex"].count()
# Out:
# stateabb
# AAB     36
# AFG     98
# ALB     99
# ALG     55
# AND     24
#       ...
# YPR     24
# YUG    137
# ZAM     53
# ZAN      2
# ZIM     52
# Name: milex, Length: 217, dtype: int64

# %% [raw]
# with zipfile.ZipFile("NMC-60-wsupplementary.zip", "r") as nmcSup:
#     nmcSup.extractall("nmcSup")

# %%
nmcSup= pd.read_csv("D:/PhD/Dataset/CoW/nmcSup/NMC-60-wsupplementary.csv", encoding = "latin-1")
nmcSup.head()
# Out:
#                    statenme stateabb  ccode  year  milex milexsource  \
# 0  United States of America      USA      2  1816   3823         NaN
# 1  United States of America      USA      2  1817   2466         NaN
# 2  United States of America      USA      2  1818   1910         NaN
# 3  United States of America      USA      2  1819   2301         NaN
# 4  United States of America      USA      2  1820   1556         NaN
#
#   milexnote  milper                                       milpersource  \
# 0       NaN      17  (U.S. Department of Commerce and Bureau of the...
# 1       NaN      15  (U.S. Department of Commerce and Bureau of the...
# 2       NaN      14  (U.S. Department of Commerce and Bureau of the...
# 3       NaN      13  (U.S. Department of Commerce and Bureau of the...
# 4       NaN      15  (U.S. Department of Commerce and Bureau of the...
#
#                  milpernote  ...  tpopanomalycode   upop  upopsource  \
# ...

# %%
nmcSup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15951 entries, 0 to 15950
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   statenme          15951 non-null  object
#  1   stateabb          15951 non-null  object
#  2   ccode             15951 non-null  int64
#  3   year              15951 non-null  int64
#  4   milex             15951 non-null  int64
#  5   milexsource       7915 non-null   object
#  6   milexnote         3924 non-null   object
#  7   milper            15951 non-null  int64
#  8   milpersource      12905 non-null  object
#  9   milpernote        5925 non-null   object
#  10  irst              15951 non-null  int64
#  11  irstsource        15861 non-null  object
#  12  irstnote          9814 non-null   object
#  13  irstqualitycode   15926 non-null  object
#  14  irstanomalycode   15926 non-null  object
#  15  pec               15951 non-null  int64
# ...

# %% [raw]
# zfSup = zipfile.ZipFile(r"NMC_5_0-wsupplementary.zip")
# nmcSup = pd.read_csv(zfSup.open("NMC_5_0-wsupplementary.csv"), encoding = "latin-1")
# nmcSup.head()

# %%
nmcSup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15951 entries, 0 to 15950
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   statenme          15951 non-null  object
#  1   stateabb          15951 non-null  object
#  2   ccode             15951 non-null  int64
#  3   year              15951 non-null  int64
#  4   milex             15951 non-null  int64
#  5   milexsource       7915 non-null   object
#  6   milexnote         3924 non-null   object
#  7   milper            15951 non-null  int64
#  8   milpersource      12905 non-null  object
#  9   milpernote        5925 non-null   object
#  10  irst              15951 non-null  int64
#  11  irstsource        15861 non-null  object
#  12  irstnote          9814 non-null   object
#  13  irstqualitycode   15926 non-null  object
#  14  irstanomalycode   15926 non-null  object
#  15  pec               15951 non-null  int64
# ...

# %%
nmcSup[nmcSup["stateabb"].str.contains("TUR", regex=False)]
# Out:
#       statenme stateabb  ccode  year     milex milexsource milexnote  milper  \
# 12269   Turkey      TUR    640  1816        -9         NaN       NaN     121
# 12270   Turkey      TUR    640  1817        -9         NaN       NaN     121
# 12271   Turkey      TUR    640  1818        -9         NaN       NaN     121
# 12272   Turkey      TUR    640  1819        -9         NaN       NaN     141
# 12273   Turkey      TUR    640  1820        -9         NaN       NaN     161
# ...        ...      ...    ...   ...       ...         ...       ...     ...
# 12465   Turkey      TUR    640  2012  10167000   IISS/2014       NaN     511
# 12466   Turkey      TUR    640  2013  10742000   IISS/2018       NaN     511
# 12467   Turkey      TUR    640  2014  10047000   IISS/2018       NaN     511
# 12468   Turkey      TUR    640  2015   8347000   IISS/2018       NaN     511
# 12469   Turkey      TUR    640  2016   8764000   IISS/2018       NaN     511
#
# ...

# %%
with zipfile.ZipFile("D:/PhD/Dataset/The_CoW_Project/Militarized_Interstate_Disputes_(v5.0)/MID 5 Data and Supporting Materials.zip", "r") as mid:
    print(mid.namelist())
# Out:
# ['Dispute Coding Manual.pdf', 'Incident Coding Manual.pdf', 'MID Articles Reviewed by Coders.xlsx', 'MID Narratives 2011-2014.pdf', 'MID_Narratives_1993-2001.pdf', 'MID_Narratives_2002-2010.pdf', 'MID5 Draft Article of Record with Title Page.pdf', 'MIDA 5.0.csv', 'MIDA 5.0.dta', 'MIDB 5.0.csv', 'MIDB 5.0.dta', 'MIDI 5.0.csv', 'MIDI 5.0.dta', 'MIDIP 5.0.csv', 'MIDIP 5.0.dta', 'MID 5.0 Codebook.pdf']

# %%
with zipfile.ZipFile("D:/PhD/Dataset/The_CoW_Project/Militarized_Interstate_Disputes_(v5.0)/MID 5 Data and Supporting Materials.zip", "r") as mid:
    mid.extractall("D:/PhD/Dataset/The_CoW_Project/Militarized_Interstate_Disputes_(v5.0)/MID_v5.0")

# %%
mida = pd.read_csv("D:/PhD/Dataset/The_CoW_Project/Militarized_Interstate_Disputes_(v5.0)/MID_v5.0/MIDA 5.0.csv")

# %%
mida.head()
# Out:
#    dispnum  stday  stmon  styear  endday  endmon  endyear  outcome  settle  \
# 0        2     -9      7    1902      24       1     1903        6       1
# 1        3      2      5    1913      25      10     1913        4       3
# 2        4     15      5    1946      13      11     1946        5       3
# 3        7     13     10    1951      26       1     1952        1       3
# 4        8     -9      7    1856      14       3     1857        1       2
#
#    fatality  fatalpre  maxdur  mindur  hiact  hostlev  recip  numa  numb  \
# 0         0         0     208     178      7        3      0     1     1
# 1         0         0     177     177      8        3      0     1     1
# 2         2        -9     183     183     16        4      1     1     1
# 3         2        -9     106     106     17        4      1     1     1
# 4         6        -9     257     227     20        5      1     1     1
#
#    ongo2014  version
# 0         0        5
# 1         0        5
# ...

# %%
mida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2436 entries, 0 to 2435
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   dispnum   2436 non-null   int64
#  1   stday     2436 non-null   int64
#  2   stmon     2436 non-null   int64
#  3   styear    2436 non-null   int64
#  4   endday    2436 non-null   int64
#  5   endmon    2436 non-null   int64
#  6   endyear   2436 non-null   int64
#  7   outcome   2436 non-null   int64
#  8   settle    2436 non-null   int64
#  9   fatality  2436 non-null   int64
#  10  fatalpre  2436 non-null   int64
#  11  maxdur    2436 non-null   int64
#  12  mindur    2436 non-null   int64
#  13  hiact     2436 non-null   int64
#  14  hostlev   2436 non-null   int64
#  15  recip     2436 non-null   int64
#  16  numa      2436 non-null   int64
#  17  numb      2436 non-null   int64
#  18  ongo2014  2436 non-null   int64
#  19  version   2436 non-null   int64
# dtypes: int64(20)
# ...

# %%
midb = pd.read_csv("D:/PhD/Dataset/The_CoW_Project/Militarized_Interstate_Disputes_(v5.0)/MID_v5.0/MIDB 5.0.csv")

# %%
midb.head()
# Out:
#    dispnum stabb  ccode  stday  stmon  styear  endday  endmon  endyear  sidea  \
# 0        2   UKG    200     -9      7    1902      24       1     1903      0
# 1        2   USA      2     -9      7    1902      24       1     1903      1
# 2        3   YUG    345      2      5    1913      25      10     1913      0
# 3        3   AUH    300      2      5    1913      25      10     1913      1
# 4        4   UKG    200     15      5    1946      13      11     1946      0
#
#    revstate  revtype1  revtype2  fatality  fatalpre  hiact  hostlev  orig  \
# 0         1         1        -9         0         0      0        1     1
# 1         1         1        -9         0         0      7        3     1
# 2         0         0        -9         0         0      0        1     1
# 3         1         2        -9         0         0      8        3     1
# 4         0         0        -9         2        -9      7        3     1
#
#    version
# 0        5
# 1        5
# 2        5
# ...
