# %% [markdown]
# ## Functions

# %% [markdown]
# Block of code that executes already designed logic when it is called. (prints text, deletes data or square a number)
# To define a Pfunction, **def** keyword is used.

# %% [markdown]
# Functions provide organized, reusable and modular code to perform a set of speciﬁc actions. Functions simplify coding process.
# You can enter or input data, known as arguments, into a function and it returns/outputs something good that you want.

# %% [markdown]
# ### Writing and reading a function

# %% [markdown]
# Difference between parameter and argument: slightly different from each other. Parameter is the name of variable. Argument is the value.

# %%
#def myfunc-fonksiyon adı(parametre):
    #execute some sort of code

# %%
a = 3
b = 5
def multiply(a,b):#multiply: name of function, a,b-->parameters
    print(a*b)

# %% [markdown]
# ### Calling a function

# %% [markdown]
# Calling a function means using it. When you need a function in your codes, you simply use it. For example, if you want to multiply two numbers, you can just write the name of that function and the numbers (arguments) inside the parenthesis. By doing this, you have actually called this function.

# %% [markdown]
# If the name of a function is followed by parentheses, it means that it was called to get the result.

# %%
multiply(3,5)#3,5--> arguments
# Out:
# 15

# %%
multiply("functions are so useful ", 3)
# Out:
# functions are so useful functions are so useful functions are so useful

# %% [markdown]
# ### Execution of function

# %% [markdown]
# Functions did not return any types or values but executed some actions.

# %% [markdown]
# To use later the output and dts generated by the functions, we need to define our function using the keyword **return** in addition to def.

# %% [markdown]
# ### Return Keyword

# %% [markdown]
# The purpose of a function is to receive the inputs and return some output. The return is a Python statement which we can use in a function for sending a value back to its caller.

# %%
def multiply1(a,b):
    print(a*b)#it prints something

# %%
multiply1(2,3)# just prints some data that you passed into.
# Out:
# 6

# %%
def multiply2(a,b):
    return a*b #returns any numeric data type value

# %%
multiply2(2,3)# generates a numeric type value.
# Out:
# 6

# %%
print(type(multiply1(2,3)))#We can't use the result of the first function since it is NoneType data. 
print(type(multiply2(2,3)))#We can use the result of second one since it is integer data.
# Out:
# 6
# <class 'NoneType'>
# <class 'int'>

# %%
shadow_var = print("It can't be assigned to any variable")
# Out:
# It can't be assigned to any variable

# %%
print(shadow_var)  # NoneType value can't be used
# Out:
# None

# %% [markdown]
# ### Examples

# %%
# Out:
# First name is Guido
# Last name is van Rossum

# %% [markdown]
# ### Correct Use of Arguments

# %% [markdown]
# When calling a function, there are several ways to use arguments.

# %% [markdown]
# #### Positional Arguments

# %%
Positions (sequence) of the arguments matter. When calling a function with posar, they must be passed in order from ltor.

# %%
def posar(a,b):
    print(a, "is the first argument")
    print(b, "is the second argument")

# %%
posar(3,4)
# Out:
# 3 is the first argument
# 4 is the second argument

# %%
posar(4,3)
# Out:
# 4 is the first argument
# 3 is the second argument

# %% [markdown]
# #### Keyword Arguments

# %% [markdown]
# If you do not want posar to restrict you, you can call these arguments by keywords.

# %% [markdown]
# The formula syntax is : **kwargs=values**

# %%
def who(first, last):#parameters 
    print("Your first name is :" , first)
    print("Your last name is :", last)
#who("Guido", "van Rossum")#arguments
who(first='Guido', last='van Rossum')  # kwargs to pass values into the function
# Out:
# Your first name is : Guido
# Your last name is : van Rossum

# %%
def parrot(voltage, state='a stiff', action='voom', type='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", type)
    print("-- It's", state, "!")

# %%
parrot(1000) # 1 pa
# Out:
# -- This parrot wouldn't voom if you put 1000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot(voltage=1000) # 1 kwargs
# Out:
# -- This parrot wouldn't voom if you put 1000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot(voltage=1000000, action='VOOOOOM') # 2 kwargs
# Out:
# -- This parrot wouldn't VOOOOOM if you put 1000000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot('a million', 'bereft of life', 'jump') # 3 pas
# Out:
# -- This parrot wouldn't jump if you put a million volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's bereft of life !

# %%
parrot('a thousand', state='pushing up the daisies')  # 1 p, 1 kw
# Out:
# -- This parrot wouldn't voom if you put a thousand volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's pushing up the daisies !

# %% [markdown]
# 💡Tips: positions of the parameters voltage and action, sequences or positions don't matter when using kwargs.

# %% [markdown]
# Considering the defined functions, all the following calls would be invalid

# %%
parrot()# required argument missing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ff8f8441954a> in <module>
# ----> 1 parrot()# required argument missing
#
# TypeError: parrot() missing 1 required positional argument: 'voltage'

# %%
parrot(voltage=5.0, 'dead')  # non-ka after a ka
# Out:
#   File "<ipython-input-18-e74beb13def7>", line 1
#     parrot(voltage=5.0, 'dead')  # non-ka after a ka
#                        ^
# SyntaxError: positional argument follows keyword argument

# %%
parrot(110, voltage=220)     # duplicate value for the same argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-be58d87c4290> in <module>
# ----> 1 parrot(110, voltage=220)     # duplicate value for the same argument
#
# TypeError: parrot() got multiple values for argument 'voltage'

# %%
parrot(actor='John Cleese')  # unknown ka
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-652bfa07d737> in <module>
# ----> 1 parrot(actor='John Cleese')  # unknown ka
#
# TypeError: parrot() got an unexpected keyword argument 'actor'

# %% [markdown]
# In a function call, kwargs must follow posar. All the kwargs passed must match one of the arguments accepted by the function (e.g. actor is not a valid argument for the parrot function), and their order is not important.
# This also includes non-optional arguments (e.g. parrot(voltage=1000) is valid too). No argument may receive a value more than once. Here’s an example that fails due to this restriction:

# %%
def function(a):
    pass   
function(0, a=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-94e5e7ef597a> in <module>
#       1 def function(a):
#       2     pass
# ----> 3 function(0, a=0)
#
# TypeError: function() got multiple values for argument 'a'

# %%
def myfunc(param1):
    print(param1)

# %%
myfunc("yazdırabildinni gardaş?")
# Out:
# yazdırabildinni gardaş?

# %%
def myfunc(param1):
    print(param1)

# %%
myfunc(1)
# Out:
# 1

# %%
def myfunc(name="default"):
    print("hello "+name)

# %%
myfunc("gurkan")
# Out:
# hello gurkan

# %%
def myfunc(name = "Default name"):
    print("Hello "+name)

# %%
myfunc(name = "gurkan")
# Out:
# Hello gurkan

# %%
def first_function(parameter_1, parameter_2):
    print(parameter_1**2 + parameter_2**2)

# %%
parameter_1 = 2
parameter_2 = 3

# %%
def kare(a,b): #a ve b parametrelerimiz
    print(a**2 + b**2) # kare fonksiyonunu her çağırdığımızda bu print satırını işletecek

# %%
kare(3,5)# 3 ve 5 argümanlar, kare fonksiyonunu yazınca çağırmış olduk

# %%
type(kare(3,4))

# %%
def multiply(a,b):
    print(a*b)

# %%
multiply(3,5)
multiply(-1, 2.5)
multiply("amazing", 3) # it is realyy amazing, right?, dikkat: *'i def fonktan alır

# %%
def motto():#parametre kullanmak zorunda değiliz
    print("Devam yakalarsın")
motto()#it takes no argument

# %%
def sum(a,b):
    print(a+b)

# %%
sum(1,2)

# %%
def calculator(a,b):
    print(a+b)
    print(a-b)
    print(a*b)
    print(a/b)

# %%
calculator(3,2)

# %%
def calcu (x,y, opr):
    if opr == "+":
        print(x+y)
    elif opr == "-":
        print(x-y)
    elif opr == "*":
        print(x*y)
    elif opr == "/":
        print(x/y)
    else: print("enter valid argument")

# %%
calcu(1,2,"-")

# %%
def multiply_1(a, b):
    print(a*b) #it prints something

# %%
multiply_1(10,5)
print(type(multiply_1(10,5)))#nonetype fonksiyonun kendisinin tipi yani printin.

# %%
def multiply_2(a, b):
    return(a*b) #returns any numeric dt value, fonksiyonununzun ürettiği herhangi bir şeyi döndürebilirsiniz. 
print(multiply_2(10,5))
print(type(multiply_2(10,5)))

# %%
def karışık(a, b):
    x = a * b
    y = a + b
    z = a / b
    return y # fonksiyonun neyi döndürmesi gerektiğini seçebiliriz. burda sadece y,

# %%
karışık(8,4)

# %%
def toplam(a, b):
    return(a+b)

# %%
toplam(3, 4)

# %%
yeni = toplam(3, 4)# return olduğu için sonuç yeni bir değişkene atanabilir.

# %%
print(yeni)

# %%
def multi(a, b):
    print(a*b) # printin tipi nonetype olduğu için değişkene atanamıyor

# %%
multi(5, 4)

# %%
değişken = multi(5, 4)

# %%
print(değişken)

# %%
shadow_var = print("It can't be assigned to any variable")
print(shadow_var) # Nonetype value can't be used

# %%
def calcu (x,y, opr):
    if opr == "+":
        return(x+y)
    elif opr == "-":
        return(x-y)
    elif opr == "*":
        return(x*y)
    elif opr == "/":
        return(x/y)
    else: return("enter valid argument")

# %%
calcu(1,2,"/")

# %%
def hangisi(x, z):
    return x
    return z

# %%
hangisi(2, 5)

# %%
def absolute_value(num):
    """this function returns the absolute value
    """
    if num >= 0:
        return num
    else: return -num

# %%
absolute_value(-12)

# %%
print(absolute_value.__doc__)#docstr,ng getirme metodu

# %%
print(print.__doc__)

# %%
def my_function(a, b):
    print(a*b)

# %%
print(my_function(3, 4))

# %%
def my_functions(a, b):
    print((a**2 + b**2)**0.5)

# %%
my_functions(3, 4)

# %%
def my_functions(a, b):
    hypotenuse = (a**2 + b**2)**0.5
    print(hypotenuse)

# %%
my_functions(3, 4)

# %%
def my_function(a, b)
    area = a*b
    return area

# %%
def my_functions(a, b):
    hypotenuse = (a**2 + b**2)**0.5
    return(hypotenuse)

# %%
my_functions(3, 4)

# %%
def toplam(a, b):
    print(a+b)

# %%
toplam(3, 4)

# %%
def multiply_1(a, b):
    print(a* b)

# %%
multiply_1(5, 10)

# %%
print(type(multiply_1(10, 5)))

# %%
def multiply_2(a, b):
    return a * b  # returns any numeric data type value

# %%
multiply_2(5, 10)

# %%
print(type(multiply_2(10, 5)))

# %%
shadow_var = print("It can't be assigned to any variable")
print(shadow_var)  # NoneType value can't be used

# %%
def my_function(a,b):
    hypotenuse = (a**2 + b**2)**0.5
    return hypotenuse

# %%
my_function(3,4)

# %%
def my_function(a, b):
    area = a*b
    return area

# %%
my_function(3,4)

# %%
def longer(a, b):
    if len(a) >= len(b):
        return a
    else:
        return b

print(longer('Richard', 'John'))

# %%
def who(first, last):  # 'first' and 'last' are the parameters(or variables)
   print("Your first name is :", first)
   print("Your last name is :", last)

# %%
who("Guido", "van Rossum") # 'Guido' and 'van Rossum' are the arguments
who("gürkan")
#print()

# %%
def pos_args(a, b):
    print(a, "is the first argument")
    print(b, "is the second argument")

# %%
pos_args(3, 4)

# %%
pos_args(4, 3)

# %%
def who(first, last):
    print("Your first name is: ", first)
    print("Your last name is: ", last)

# %%
who(last = "van Rossum", first = "Guido")

# %%
def parrot(voltage, state='a stiff', action='voom', type='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", type)
    print("-- It's", state, "!")

# %%
parrot(voltage=5.0)

# %%
parrot()

# %%
parrot('a thousand', state='pushing up the daisies')

# %%
parrot('a million', 'bereft of life', 'jump')

# %%
parrot(1000)                                          # 1 positional argument

# %%
parrot(voltage=1000)

# %%
parrot(voltage=1000000, action='VOOOOOM')

# %%
parrot(action='VOOOOOM', voltage=1000000)

# %%
parrot('a million', 'bereft of life', 'jump')

# %%
def function(a):
    pass  # actually, 'pass' does nothing. it just moves to the next line of code
function(0, a=0)

# %%
def city(capital, continent = "Europe"):
    print(capital, "in", continent)

# %%
city("Athens")  # we don't have to pass any arguments into 'continent'

# %%
city("Ulaanbaatar", continent = "Asia") # we can change the default value by kwargs

# %%
city("Cape Town", "Africa") # we can change the default value by positional args.

# %%
def fruiterer(fruit1, fruit2):
    print("I want to get", fruit1, "and", fruit2)

# %%
fruiterer("orange", "banana")

# %%
def fruiterer(*fruit):
    print("I want to get: ")
    for i in fruit:
        print("-", i)

# %%
fruiterer("orange", "banana", "melon", "ananas")

# %%
def animals(**kwargs):
    for key, value in kwargs.items():
        print(value, "are", key)

# %%
animals(Carnivores="Lions", Omnivores = "Bears", Herbivores = "Deers", Nomnivores = "Human")

# %%
def brothers(bro1, bro2, bro3, bro4):
    print("Here are the names of brothers:")
    print(bro1, bro2, bro3, bro4, sep = "\n")

# %%
family = ["büşra", "ahmet selim", "sinem", "okan"]

# %%
brothers(*family)

# %%
def get_initial(name):
    initial = name[0:1].upper()
    return(initial)

# %%
first_name = input("Enter your first name: ")
first_name_initial = get_initial(first_name)

# %%
print("Your initial is: " + first_name_initial)

# %%
def get_initial(name, force_uppercase):
    if force_uppercase:
        initial = name[0:1].upper()
    else:
        initial = name[0:1]
    return(initial)

# %%
first_name = input("Enter your first name: ")
first_name_initial = get_initial(first_name, False)

# %%
print("Your initial is: " + first_name_initial)

# %%
def team_names(*teams) :
    print('The teams in Premier League are :')
    for i in teams :
        print('-', i)

team_names('Liverpool', 'M.United', 'M.City', 'Arsenal')

# %%
def make_sentence(**kwargs):
    result = ""
    # Iterating over the Python kwargs dictionary
    for i in kwargs.values():
        result += i
    return result

print(make_sentence(a="I ", b="love ", c="Clarusway!"))

# %%
def who(first, last):
    print(first, last)

# %%
who(first = "Gürkan", last = "Yeşilyurt")

# %%
def team_league(team, league='Premier League'):
    print(team, 'in', league)

team_league('Liverpool')

# %%
def my_function(first, last) : 
    print('Your first name is :', first)
    print('Your last name is :', last)

my_function(first='Richard', last='Rice')

# %%
def name_surname(first, second):
    print("my first name is:", first, ",", "my surname is: ", second)

# %%
name_surname("gürkan", "yeşilyurt")

# %%
name_surname("canan", "yeşilyurt")

# %%
a = "i"
b = "love"
c = "you"

def texter(c = "you", a = "i", b = "love"):
    print(a, b, c)

# %%
texter()

# %%
def texter(t1, t2, t3):
    print(f"{t2} {t3} {t1}")

# %%
a = "i"
b = "love"
c = "you"

# %%
texter(c, a, b)

# %%
def who(first, last):
    print("My first name is: ", first)
    print("My last name is: ", last)

# %%
who("gürkan", "yeşilyurt")

# %%
who(last = "yeşilyurt", first = "canan")

# %%
def texter(t1, t2, t3):
    print(f"{t2} {t3} {t1}")

# %%
texter(t2 = "i", t3 = "love", t1 = "you")

# %%
def parrot(voltage, state='a stiff', action = "voom", type='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", type)
    print("-- It's", state, "!")

# %%
parrot(1000)

# %%
parrot(voltage = 1000)

# %%
def parrot(voltage, state='a stiff', action = "voom", type='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", type)
    print("-- It's", state, "!")

# %%
print(voltage = 10000000)

# %%
def slicer(*numbers):
    even = []
    odd = []
    for i in numbers:
        if i % 2 != 0:
            odd.append(i)
        else: 
            even.append(i)
    print("even:", even)
    print("odd:" , odd)

# %%
slicer(1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
def slicer(*num):
    even = [i for i in num if i %2 == 0]
    odd = [j for j in num if j %2 != 0]
    print("even:", even)
    print("odd:" , odd)

# %%
slicer(1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
def animals(**kwargs):
    for key, value in kwargs.items():
        print(value, "are", key)

# %%
animals(Carnivores = "Lions", Omnivores = "Bears", Herbivores = "Deers", Nomnivores = "Human")

# %%
def organizer(**kwargs):
    names = []
    ages = []
    for key, value in kwargs.items():
        names.append(key)
        ages.append(value)
    print(names)
    print(ages)

# %%
organizer(Beth=26, Oscar=42, Justin=18, FRank=33)

# %%
def bros(bro1, bro2, bro3):
    print("Here are the names of brothers: ")
    print(bro1, bro2, bro3, sep = "\n")

# %%
family = ["tom", "sue", "tim"]

# %%
bros(*family)

# %%
def merger(arg1, arg2, arg3, arg4):
    print(f"For me, {arg1} {arg4} and {arg3} {arg2} are geniuses.")

# %%
genius = ("Bill", "Rossum", "Guido van", "Gates")

# %%
merger(*genius)

# %%
def gene(x, y): #defined by pas
    print(x, "belongs to Generation X")
    print(y, "belongs to Generation Y")

# %%
dict_gene = {"y" : "Marry", "x" : "Fred"} # sözlük ** ile fonksiyona sokulmuş

# %%
gene(**dict_gene)# we call the function by a single argument (variable)

# %%
def meaner(İbo, Ömer, Hüseyin):
    avg = (İbo + Ömer + Hüseyin)/3
    return avg

# %%
friends = {"İbo" : 43, "Ömer" : 40 , "Hüseyin" : 28}

# %%
print(meaner(**friends))

# %%
def gene(x = "Solomon", y = "David"): #defined by kwargs
    print(x, "belongs to Generation X")
    print(y, "belongs to Generation Y")

# %%
dict_gene = {"y" : "Marry", "x" : "Fred"}

# %%
gene(**dict_gene)

# %%
my_var = "outer variable" #name of variable used here

def func_var():
    my_var = "inner variable" #name of variable used here also
    print(my_var)
    
func_var() #the same variable produces different outputs
print(my_var)

# %%
text = "I am the global one"
def global_func():
   print(text)       # we can use 'text' in a function, # because it's a global variable

# %%
global_func()  # 'I am the global one' will be printed

# %%
print(text)

# %%
text = "The globals are valid everywhere "

# %%
global_func()

# %%
x = 10
def my_function_1(): 
    x = 20 
    print(x)
    
print(x)

# %%
def local_func():
    local_text = "I am the local one"
    print(local_text)  # local_text is a local variable

# %%
local_func()  # 'I am the local one' will be printed as expected

# %%
print(local_text)  # NameError will be raised, # because we can't use local variable outside of its function

# %%
variable = "global"

def func_outer():
    variable = "enclosing outer local"
       
    def func_inner():
        variable = "enclosing inner local"
       
        def func_local():
            variable = "local"
            print(variable)
        
        func_local()
        print(variable)
    
    func_inner()
    print(variable)

func_outer()  # prints 'local' defined in the innermost function
print(variable)  # 'global' level variable holds its value

# %%
count = 1

# %%
def print_global():
    print(count)

# %%
print_global()

# %%
def counter():
    print(count)
    count += 1  # we're trying to change its value

# %%
print()  # just empty line
counter()

# %%
count = 1
def counter():
    count = 2
    print(count)

# %%
counter()

# %%
foo()

# %%
def foo():
    y = "local" # y is a lv.

# %%
foo()

# %%
print(y)# we have tried to use lv y in a global scope.

# %%
def foo():
    y = "local" # y is a lv.   
    print(y)

# %%
foo()

# %%
max = "bu benim" # max normalde bif. ama değişkene atandığında ele geçiririz. bizim verdiğimiz işi yapar

# %%
max # öncelik globalde

# %%
count = 1

def counter():
    global count #count değişkenini global hale getirdik
    print(count)
    count += 1
    
counter()

# %%
counter()

# %%
counter()

# %%
print(count)

# %%
x = 5 # at the top of the script, it is a gv.

def foo():
    x = x*2 # we have tried to change the value of gv "x"
    print(x)

# %%
foo()

# %%
def func_enclosing1():
    x = "outer variable"
    def func_enclosing2():
        x = "inner variable"
        print("inner: ", x)
    func_enclosing2()
    print("outer: ", x)
    
func_enclosing1()

# %%
def func_enclosing1():
    x = "outer variable"
    def func_enclosing2():
        nonlocal x # its inner value can be used in the outer scope
        x = "inner variable"
        print("inner: ", x)
    func_enclosing2()
    print("outer: ", x)
    
func_enclosing1()

# %%
def scope_test():
    def do_local():
        spam = "local spam"

    def do_nonlocal():
        nonlocal spam
        spam = "nonlocal spam"

    def do_global():
        global spam
        spam = "global spam"

    spam = "test spam"
    do_local()
    print("After local assignment:", spam)
    do_nonlocal()
    print("After nonlocal assignment:", spam)
    do_global()
    print("After global assignment:", spam)

scope_test()
print("In global scope:", spam)

# %%
def scope_test():
    def do_local():
        spam = "local spam"
        
    def do_nonlocal():
        nonlocal spam
        spam = "nonlocal spam"
    
    def do_global():
        global spam
        spam = "global spam"

    spam = "test spam"
    do_local()
    print("After local assignment:", spam)
    do_nonlocal()
    print("After nonlocal assignment:", spam)
    do_global()
    print("After global assignment:", spam)

scope_test()

# %%
print("In global scope:", spam)

# %%
x = 0

def bir():
    global x
    x = 5
    print(x)

# %%
bir()

# %%
def iki():
    print(x)

# %%
iki()

# %%
x = 6

# %%
iki()

# %%
var = 1
def assigner():
    global var
    var = "one"
    print(var)

# %%
assigner()

# %%
x = 10
  
def my_function(): 
    global x
    x += 5 
    print(x)

# %%
my_function()

# %%
#count = 1

def counter():
    #global count
    count += 1
    print(count)  

counter()

# %%
x = 10
def my_function_1(): 
    x = 20 
    print(x)
my_function_1()

# %%
y = 10  
def my_function_2(): 
    y += 5 
    print(y)
my_function_2()

# %%
def myfunc1():
  x = "hi"
  def myfunc2():
    nonlocal x
    x = "hello"
  myfunc2() 
  return x

print(myfunc1())

# %%
x = 'My name is Richard'
def my_function_1(): 
    x = 'My name is John' 
print(x)

# %%
my_function_1()

# %%
city = "I love Paris!"

def my_function(): 
    city = "I love London!"
    print(city)

# %%
my_function()

# %%
def outer():
    x = "previous"
    
    def inner():
        nonlocal x
        x = "later"
        print("inner:", x)
    
    inner()
    print("outer:", x)

# %%
outer()

# %%
def square(x):
    print(x**2)

# %%
square(2)

# %%
def front_back(word):#Assignment - 5 (Front-Back Char)
   word_list = list(word)
   keep_in_mind = word_list[0], word_list[-1]
   word_list[0] = keep_in_mind[1]
   word_list[-1] = keep_in_mind[0]
   return (''.join(word_list))

# %%
front_back("clarusway")
# Out:
# 'ylaruswac'

# %%
def front_back(word):#Assignment - 5 (Front-Back Char)
    if len(word) == 1:
        return word
    return word[-1] + word[1:-1] + word[0]

# %%
print(front_back('clarusway'))
print(front_back('a'))
print(front_back('ab'))
# Out:
# ylaruswac
# a
# ba

# %%
def animals(**kwargs):
    for key, value in kwargs.items():
        print(value, "are", key)

# %%
animals(Carnivores = "Lions", Omnivores = "Bears", Herbivores = "Deers")
# Out:
# Lions are Carnivores
# Bears are Omnivores
# Deers are Herbivores

# %%
def my_min(x,y):
    if x < y:
        print("minnum is: ",x)
    else: print("minnum is: ", y)

# %%
my_min(1,2)
# Out:
# minnum is:  1

# %%
def my_min(*numbers): # Assignment-6(Find Minimum)
    if [i] in numbers < [i+1]:
        print("minnum is: ",i)
    else:print("minnum is: ",i+1) 
    i +=1

# %%
def my_min(*x): # Assignment-6(Find Minimum)
    mylist = []
    for i in x:
        mylist.append(i)
    mylist.sort()
    return mylist[0]

# %%
print(my_min(3,8,-9,0,12,1.2))
# Out:
# -9

# %%
def my_sum(*i):# Assignment-7(Sum numbers)
    return sum(i)

# %%
print(my_sum(9, 1, 3, 0, -1))
# Out:
# 12

# %%
def my_fact(n):
    number = int(input("Please enter a number: "))
    factorial=1
    for i in range(1,number+1):
        factorial = i*factorial
    return factorial

# %%
print(my_fact(5))
# Out:
# Please enter a number: 5
# 120

# %%
number = int(input("Enter a number please : "))
number_list = []
factorial = 1
for i in range(number):
    number_list.append(i + 1)
n = len(number_list)
for i in range(n) :
    factorial *= number_list[i]
factorial
# Out:
# Enter a number please : 5
# 120

# %%
def faktoriyel(a):
    a = int(input("bir sayı giriniz: "))
    count = 1
    for i in range(a,0,-1):
        count *= i
    return count
faktoriyel(a)
# Out:
# bir sayı giriniz: 5
# 120

# %%
def most_freq(given_list):
    x = [given_list.count(x) for x in given_list]
    return (given_list[x.index(max(x))])

# %%
print(most_freq([1,2,3,3,3,3,4,4,5,5]))
# Out:
# 3

# %%
def repeater(n):
    return lambda x: x*n
repeat2times = repeater(2)

# %%
print(repeat2times("alex "))
# Out:
# alex alex

# %%
def functioner(n):
    return lambda x: x+n

# %%
myPrint_smile = functioner(":)")

# %%
print(myPrint_smile("Hello "))
# Out:
# Hello :)

# %%
def x():
    return 1,2,3,4

# %%
x()
# Out:
# (1, 2, 3, 4)

# %%
a, b, c, d = x()

# %%
print(a,b,c,d,)
# Out:
# 1 2 3 4

# %%
for i in x():
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
def func_generator(function):
    return lambda x : function(x)

# %%
(lambda x:print(x))("nur")
# Out:
# nur

# %%
my_print = func_generator(print)

# %%
my_print("hello world")
# Out:
# hello world

# %%
def func_generator(function):
    return lambda x : function(x)

# %%
(lambda x: max(x))([1,3,7,4,2])
# Out:
# 7

# %%
my_max = func_generator(max)

# %%
my_max([2,5,9,11])
# Out:
# 11

# %%
my_bool = func_generator(bool)

# %%
my_bool([])
# Out:
# False

# %%
my_sorted = func_generator(sorted)

# %%
my_sorted([3,1,6,8,4]) #[1,3,4,6,8]
# Out:
# [1, 3, 4, 6, 8]

# %%
def equal(a,b,c): #kaç tane sayı eşit
    nums = [a,b,c]
    res = nums.count(max(nums, key = nums.count))
    return res if res > 1 else 0

# %%
equal(1,2,2)
# Out:
# 2

# %%
res = [x,y,z].count(max([x,y,z], key = [x,y,z].count))
# Out:
# 2

# %%
equall = lambda x,y,z: [x,y,z].count(max([x,y,z], key = [x,y,z].count)) if [x,y,z].count(max([x,y,z], key = [x,y,z].count)) > 1 else 0

# %%
equal(1,2,2)
# Out:
# 2

# %%
def test(x,y,z):
    print(x,y,z)

# %%
test(1,2,3)
# Out:
# 1 2 3

# %%
testDict = {"x":1, "y":2, "z": 3}

# %%
testList = [10,20,30]

# %%
test(*testDict)
# Out:
# x y z

# %%
for i in testDict:
    print(i)
# Out:
# x
# y
# z

# %%
test(**testDict)
# Out:
# 1 2 3

# %%
test(*testList)
# Out:
# 10 20 30

# %%
nums = [1,2,3,4,5, 7, 6, 5, 2, 7, 7]

# %%
#nums.count(2)

# %%
max(nums, key=numbers.count)
# Out:
# 1

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
[1,2,3,4][1]
# Out:
# 2

# %%
sayılar = [1,2,3,4]

# %%
sayılar[1]
# Out:
# 2

# %%
(lambda x: x**3)(2)
# Out:
# 8

# %%
küp = lambda x: x**3

# %%
küp(2)
# Out:
# 8

# %%
say = [22,33,55,88,2,3,9]

# %%
çift = filter(lambda x: x%2==0, say)

# %%
list(çift)
# Out:
# [22, 88, 2]

# %%
tek= filter(lambda x: x%2!=0, say)

# %%
list(tek)
# Out:
# [33, 55, 3, 9]

# %%
#recursion, recursive: fonksiyonun sonucu kendi içinde kullanılabilir.

# %%
#4! = 4*3*2*1 = 24

# %%
def facto(n):
    if n ==1:
        return n
    else:
        return n*facto(n-1)

# %%
facto(4)
# Out:
# 24
